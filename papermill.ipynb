# %%
import papermill as pm

pm.execute_notebook(
   '/home/jovyan/scientific_project/Notebooks/Plots_ICON_11.06.2021_orig.ipynb',
   '/home/jovyan/scientific_project/Notebooks/Plots_ICON_11.06.2021.ipynb',
   parameters = dict(alpha=0.6, ratio=0.1)
)
# Out:
# Input notebook does not contain a cell with tag 'parameters'
# Executing:   0%|          | 0/18 [00:00<?, ?cell/s]
# {'cells': [{'id': '3925814a',
#    'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2021-06-12T20:29:12.072533',
#      'end_time': '2021-06-12T20:29:12.111887',
#      'duration': 0.039354,
#      'status': 'completed'},
#     'execution': {'iopub.status.busy': '2021-06-12T20:29:12.108217Z',
#      'iopub.execute_input': '2021-06-12T20:29:12.110388Z',
#      'iopub.status.idle': '2021-06-12T20:29:12.111204Z',
#      'shell.execute_reply': '2021-06-12T20:29:12.111648Z'}},
#    'execution_count': 1,
#    'source': '# Parameters\nalpha = 0.6\nratio = 0.1\n',
#    'outputs': []},
#   {'cell_type': 'markdown',
#    'id': 'f6cd13b3-5cca-4059-a4b4-f47bfd5854f5',
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2021-06-12T20:29:12.124643',
# ...
